# %% [markdown]
# <a href="https://colab.research.google.com/github/afranailaaa17/DasarPPLG-X-26/blob/main/x_PPLG_AFRANAILA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 1 MEMBUAT TIPE DATA DAN VARIABEL
# Nama Kelompok : NOVA CREW
# 1. Azril Muhammad Sonda
# 2. Cut Afra Naila Zainiati
# 3. Deliandra Kalin
# 4. Dava Mukhlis Saputra
# 5. Muhammad Adikamedian Putra
# 6. Raffa Maulana Irawan
# 7. Rizki Savari Zaki Putra

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#   string namaSiswa;
#   int umur;
#
#   cout<< "Masukan Nama (1 Kata):";
#   cin>>namaSiswa;
#
#   cout<< "Masukan Umur Anda :";
#   cin>>umur;
#
#   cout<<"\nHalo"<<namaSiswa<<",ternyata umur kamu"<<umur<<"tahun ya!"<< endl;
#   return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
! g++ input_data.cpp -o input_data
# !./input_data
# Out:
# Masukan Nama (1 Kata):
