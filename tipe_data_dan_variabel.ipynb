# %% [markdown]
# <a href="https://colab.research.google.com/github/afranailaaa17/DasarPPLG-X-26/blob/main/tipe_data_dan_variabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 1 PRAKTIK MEMBUAT TIPE DATA DAN VARIABEL
#
# Nama kelompok : Nova Crew
# 1. Azril Ramadhan Sonda
# 2. C. Afra Naila Zainiati
# 3. Deliandra kalin
# 4. Dava Mukhlis Saputra
# 5. Muhammad Adikamedian Putra
# 6. Raffa Maulana Irawan
# 7. Rizki Savario Zaki Putra

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
# // Deklarasi Variabel dan Tipe Data
# string namaBarang = "Laptop Hp";
# int jumlah = 2;
# float harga = 7500000.50;
# char kategori = 'A';
# bool tersedia = true;
#
# // Menampilkan Output ke layar
# cout << "=== DATA INVENTARIS ===" << endl;
# cout << "Nama Barang : " << namaBarang << endl;
# cout << "Kategori    : " << kategori << endl;
# cout << " Jumlah     : " << jumlah << endl;
# cout << " Harga      : Rp" << harga << endl;
# cout << " Tersedia   : " << tersedia << "(1 = Ya, 0 = Tidak)" << endl;
# cout << "=======================" << endl;
#
# return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
! g++ praktik_variabel.cpp -o praktik_variabel
