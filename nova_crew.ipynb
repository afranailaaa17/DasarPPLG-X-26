# %% [markdown]
# <a href="https://colab.research.google.com/github/afranailaaa17/DasarPPLG-X-26/blob/main/nova_crew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG BANGUN DATAR KELILLING PERSEGI PANJANG
#
# Nama Kelompok:
# 1. Azril
# 2. Afra
# 3. Delia
# 4. Dava
# 5. Dian
# 6. Raffa Maulana
# 7. Rizky

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile kelilingpersegipanjang.cpp
# #include <iostream>
# using namespace std;
# int main ()
# {
#   int p,l,keliling;
#   cout<<"program aplikasi menghitung keliling persegi panjang"<<endl;
#   cout<<"masukkan panjang :"<<endl;
#   cin>>p;
#   cout<<"masukkan lebar"<<endl;
#   cin>>l;
#
#   keliling=2*(p+l);
#
#   cout<<"tampilkan keliling persegi panjang :"<<keliling<<endl;
#   return 0;
# }
# Out:
# Overwriting kelilingpersegipanjang.cpp

# %%
# !g++ kelilingpersegipanjang.cpp -o main

# %%
! ./main
# Out:
# program aplikasi menghitung keliling persegi panjang
# masukkan panjang :
# 23
# masukkan lebar
# 23
# tampilkan keliling persegi panjang :92
